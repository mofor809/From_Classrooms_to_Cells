# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datamade/justice-divided/master/data/output/arrests_by_demographic_2013-2017.csv")
df
# Out:
#       ARREST_DATE            RACE     SEX  AGE                     STATUTE  \
# 0      2013-01-01           BLACK  FEMALE   15  625 ILCS 5.0/4-103.2-A-7-A
# 1      2013-01-01           BLACK  FEMALE   16  625 ILCS 5.0/4-103.2-A-7-A
# 2      2013-01-01           BLACK  FEMALE   16  625 ILCS 5.0/4-103.2-A-7-A
# 3      2013-01-01           BLACK  FEMALE   16    720 ILCS 5.0/12-3.05-D-4
# 4      2013-01-01           BLACK    MALE   14      625 ILCS 5.0/4-103-A-1
# ...           ...             ...     ...  ...                         ...
# 66821  2017-04-06  WHITE HISPANIC    MALE   15      720 ILCS 5.0/16-25-A-1
# 66822  2017-04-06  WHITE HISPANIC    MALE   14       720 ILCS 5.0/21-3-A-2
# 66823  2017-04-06  WHITE HISPANIC    MALE   14       720 ILCS 5.0/21-3-A-2
# 66824  2017-04-06           BLACK    MALE   17                    10-8-515
# 66825  2017-04-06           BLACK    MALE   16                    9-80-180
#
#                           STATUTE DESCRIPTION  CHARGE TYPE
# ...

# %%
#Get the distribution of races that have been charged across all 4 years
df["RACE"].value_counts(normalize = True)
#from this we are able to see that black students have recieved 78% of the punitive measures that have been given out
# Out:
# RACE
# BLACK                               0.785996
# WHITE HISPANIC                      0.171011
# WHITE                               0.031769
# BLACK HISPANIC                      0.006794
# ASIAN PACIFIC ISLANDER              0.003561
# UNKNOWN                             0.000688
# AMERICAN INDIAN / ALASKAN NATIVE    0.000180
# Name: proportion, dtype: float64

# %%
df["RACE"].value_counts()
# Out:
# RACE
# BLACK                               52525
# WHITE HISPANIC                      11428
# WHITE                                2123
# BLACK HISPANIC                        454
# ASIAN PACIFIC ISLANDER                238
# UNKNOWN                                46
# AMERICAN INDIAN / ALASKAN NATIVE       12
# Name: count, dtype: int64

# %%
df["RACE"].value_counts(normalize = True).sort_index().plot.bar()
# Out:
# <Axes: xlabel='RACE'>

# %%
unstacked_df =(df[["RACE", "STATUTE DESCRIPTION"]].value_counts().unstack()).fillna(0)
unstacked_df
# Out:
# STATUTE DESCRIPTION               18+ DEL CON/COUNT SUB TO <18  \
# RACE
# AMERICAN INDIAN / ALASKAN NATIVE                           0.0
# ASIAN PACIFIC ISLANDER                                     0.0
# BLACK                                                      1.0
# BLACK HISPANIC                                             0.0
# UNKNOWN                                                    0.0
# WHITE                                                      0.0
# WHITE HISPANIC                                             0.0
#
# STATUTE DESCRIPTION               5<15 GRAMS LSD/ANALOG  \
# RACE
# AMERICAN INDIAN / ALASKAN NATIVE                    0.0
# ASIAN PACIFIC ISLANDER                              0.0
# BLACK                                               0.0
# BLACK HISPANIC                                      0.0
# UNKNOWN                                             0.0
# WHITE                                               1.0
# ...

# %%
unstacked_df.columns
# Out:
# Index(['18+ DEL CON/COUNT SUB TO <18', '5<15 GRAMS LSD/ANALOG',
#        'AGG ASLT PC OFFICER/VOLUNTEER', 'AGG ASLT TEACHER/SCHOOL EMP',
#        'AGG ASLT/PEACE OFFICER/WEAPON', 'AGG ASLT/POLICE/SHERIFF EMP',
#        'AGG ASLT/USE DDLY WEAP/RIFLE', 'AGG ASSAULT CORR/PROBATION OFF',
#        'AGG ASSAULT HANDICAPPED/60+', 'AGG ASSAULT PC OFFICER/VOLUNTEER',
#        ...
#        'VIOLATE ORDER OF PROTECTION   ', 'VIOLATE ORDER PROTECTION',
#        'VIOLATION OF PAROLE', 'VIOLATION OF PROBATION',
#        'WALKING ALONG ROADWAYS', 'WEAPONS - UNAUTHD PSSESSION/ STORAGE',
#        'WEAPONS VIOLATION SALE OF AIR RIFLE/TOY FIREARM',
#        'WRITTEN PRESCRIPTION REQ/1ST', 'WRITTEN PRESCRIPTION REQ/SUBQ',
#        'WRONG WAY ON ONE-WAY STREET'],
#       dtype='object', name='STATUTE DESCRIPTION', length=806)

# %%
data = df[df["RACE"] == "BLACK"]
age_counts_normalized = data["AGE"].value_counts(normalize=True).sort_index()
age_counts_normalized.plot.bar()
# Out:
# <Axes: xlabel='AGE'>

# %%
row = unstacked_df.loc["BLACK"]
row.sort_values(ascending = False).head()
# Out:
# STATUTE DESCRIPTION
# ISSUANCE OF WARRANT                4157.0
# RECKLESS CONDUCT                   3561.0
# BATTERY - MAKE PHYSICAL CONTACT    2798.0
# CRIMINAL TRESPASS TO LAND          2572.0
# BATTERY - CAUSE BODILY HARM        2136.0
# Name: BLACK, dtype: float64

# %%
#what are black people getting written up for the most and how many times are they getting written up for it
row = unstacked_df.loc["BLACK"]
row.sort_values(ascending = False).head().plot.bar()
# Out:
# <Axes: xlabel='STATUTE DESCRIPTION'>

# %%
row = unstacked_df.loc["WHITE HISPANIC"]
row.sort_values(ascending = False).head()
# Out:
# STATUTE DESCRIPTION
# RECKLESS CONDUCT                         1370.0
# CANNABIS - POSSESS LESS THAN 2.5 GRMS     866.0
# CANNABIS - POSSESS 2.5-10 GRMS            696.0
# ISSUANCE OF WARRANT                       580.0
# CRIMINAL TRESPASS TO LAND                 477.0
# Name: WHITE HISPANIC, dtype: float64

# %%
#what are white hisapnics getting written up for
row = unstacked_df.loc["WHITE HISPANIC"]
row.sort_values(ascending = False).head().plot.bar()
# Out:
# <Axes: xlabel='STATUTE DESCRIPTION'>

# %%
row = unstacked_df.loc["WHITE"]
row.sort_values(ascending = False).head()
# Out:
# STATUTE DESCRIPTION
# RETAIL THEFT/DISP MERCH/<$300            163.0
# CANNABIS - POSSESS LESS THAN 2.5 GRMS    131.0
# CANNABIS - POSSESS 2.5-10 GRMS           123.0
# RECKLESS CONDUCT                         119.0
# ISSUANCE OF WARRANT                      119.0
# Name: WHITE, dtype: float64

# %%
#what are the white coutnerparts getting written up for
row = unstacked_df.loc["WHITE"]
row.sort_values(ascending = False).head().plot.bar()
# Out:
# <Axes: xlabel='STATUTE DESCRIPTION'>

# %%
#able to see the likelihood for charge type by race
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Define custom colormap
custom_colors = ["#ADD8E6", "yellow", "#FF3278"]
cmap = LinearSegmentedColormap.from_list("custom_cmap", custom_colors)

# Crosstab and heatmap
ct = pd.crosstab(df["RACE"], df["CHARGE TYPE"], normalize='index')
sns.heatmap(ct, annot=True, cmap=cmap)

# Labels and title
plt.rcParams['font.family'] = 'serif'
plt.title("Likelihood of Charge Type by Race",fontname='serif', fontsize=20)
plt.ylabel("Race")
plt.xlabel("Charge Type")

plt.savefig("charge_type_by_race.png", dpi=300, bbox_inches='tight')

plt.show()


#felonies are known to be harsher than misdeanors becasue they carry mroe severe and long term punishments
#sentences for felonies are usually more than a year while a misdeamonor is usually up to one year in county jail
#interesting to see how the likelihood for Black chidlren in chicago to get a misdeamor is the higest out of every race
#while the likehood for white children adn children of other races get a misdemeanor is higher than other races

# %%
import matplotlib.font_manager
print([f.name for f in matplotlib.font_manager.fontManager.ttflist])
# Out:
# ['cmss10', 'STIXSizeThreeSym', 'STIXSizeOneSym', 'STIXSizeThreeSym', 'STIXGeneral', 'DejaVu Serif Display', 'STIXNonUnicode', 'STIXSizeFourSym', 'STIXGeneral', 'STIXSizeTwoSym', 'DejaVu Sans Mono', 'STIXSizeOneSym', 'STIXSizeTwoSym', 'DejaVu Sans Display', 'DejaVu Serif', 'DejaVu Serif', 'cmtt10', 'DejaVu Serif', 'STIXNonUnicode', 'DejaVu Sans', 'DejaVu Sans', 'STIXGeneral', 'cmmi10', 'cmb10', 'cmsy10', 'STIXNonUnicode', 'STIXNonUnicode', 'DejaVu Sans Mono', 'DejaVu Sans Mono', 'STIXSizeFiveSym', 'STIXGeneral', 'DejaVu Sans', 'cmr10', 'STIXSizeFourSym', 'cmex10', 'DejaVu Serif', 'DejaVu Sans Mono', 'DejaVu Sans', 'Liberation Mono', 'Liberation Serif', 'Humor Sans', 'Liberation Sans Narrow', 'Liberation Mono', 'Liberation Sans Narrow', 'Liberation Serif', 'Liberation Sans', 'Liberation Mono', 'Liberation Mono', 'Liberation Sans', 'Liberation Sans', 'Liberation Serif', 'Liberation Sans', 'Liberation Sans Narrow', 'Liberation Sans Narrow', 'Liberation Serif']

# %%
from google.colab import files
files.download("charge_type_by_race.png")

# %%
df['ARREST_DATE'] = pd.to_datetime(df['ARREST_DATE'])
df['ARREST_YEAR'] = df['ARREST_DATE'].dt.year

# Data for 2013
df_2013 = df[df['ARREST_YEAR'] == 2013]
print("Data for 2013:")
display(df_2013.head())

# Data for 2014
df_2014 = df[df['ARREST_YEAR'] == 2014]
print("\nData for 2014:")
display(df_2014.head())

# Data for 2015
df_2015 = df[df['ARREST_YEAR'] == 2015]
print("\nData for 2015:")
display(df_2015.head())

# Data for 2016
df_2016 = df[df['ARREST_YEAR'] == 2016]
print("\nData for 2016:")
display(df_2016.head())

# Data for 2017
df_2017 = df[df['ARREST_YEAR'] == 2017]
print("\nData for 2017:")
display(df_2017.head())
# Out:
# Data for 2013:
#   ARREST_DATE   RACE     SEX  AGE                     STATUTE  \
# 0  2013-01-01  BLACK  FEMALE   15  625 ILCS 5.0/4-103.2-A-7-A
# 1  2013-01-01  BLACK  FEMALE   16  625 ILCS 5.0/4-103.2-A-7-A
# 2  2013-01-01  BLACK  FEMALE   16  625 ILCS 5.0/4-103.2-A-7-A
# 3  2013-01-01  BLACK  FEMALE   16    720 ILCS 5.0/12-3.05-D-4
# 4  2013-01-01  BLACK    MALE   14      625 ILCS 5.0/4-103-A-1
#
#                     STATUTE DESCRIPTION CHARGE TYPE  ARREST_YEAR
# 0   UNLAWFUL POSS/DRIVER/VEHICLE/STOLEN      FELONY         2013
# 1   UNLAWFUL POSS/DRIVER/VEHICLE/STOLEN      FELONY         2013
# 2   UNLAWFUL POSS/DRIVER/VEHICLE/STOLEN      FELONY         2013
# 3             AGG BATTERY/PEACE OFFICER      FELONY         2013
# 4  RECEIVE/POSSESS/SELL  STOLEN VEHICLE      FELONY         2013
# Data for 2014:
#       ARREST_DATE   RACE   SEX  AGE                  STATUTE  \
# 21265  2014-01-01  BLACK  MALE   17  720 ILCS 5.0/24-1.8-A-1
# ...
